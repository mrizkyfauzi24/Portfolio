# %%
import pandas as pd
import numpy as np

data = pd.read_csv('london_bikes_csv_final.csv')

# %%
data.head(10)
# Out:
#                   time  count  temp_real_c  temp_feels_like_c  \
# 0  2015-01-04 00:00:00    182          3.0                2.0
# 1  2015-01-04 01:00:00    138          3.0                2.5
# 2  2015-01-04 02:00:00    134          2.5                2.5
# 3  2015-01-04 03:00:00     72          2.0                2.0
# 4  2015-01-04 04:00:00     47          2.0                0.0
# 5  2015-01-04 05:00:00     46          2.0                2.0
# 6  2015-01-04 06:00:00     51          1.0               -1.0
# 7  2015-01-04 07:00:00     75          1.0               -1.0
# 8  2015-01-04 08:00:00    131          1.5               -1.0
# 9  2015-01-04 09:00:00    301          2.0               -0.5
#
#    humidity_percent  wind_speed_kph        weather  is_holiday  is_weekend  \
# 0             0.930             6.0  broken clouds         0.0         1.0
# 1             0.930             5.0          clear         0.0         1.0
# ...

# %%
data.describe()
# Out:
#               count   temp_real_c  temp_feels_like_c  humidity_percent  \
# count  17414.000000  17414.000000       17414.000000      17414.000000
# mean    1143.101642     12.468091          11.520836          0.723250
# std     1085.108068      5.571818           6.615145          0.143132
# min        0.000000     -1.500000          -6.000000          0.205000
# 25%      257.000000      8.000000           6.000000          0.630000
# 50%      844.000000     12.500000          12.500000          0.745000
# 75%     1671.750000     16.000000          16.000000          0.830000
# max     7860.000000     34.000000          34.000000          1.000000
#
#        wind_speed_kph    is_holiday    is_weekend
# count    17414.000000  17414.000000  17414.000000
# mean        15.913063      0.022051      0.285403
# std          7.894570      0.146854      0.451619
# min          0.000000      0.000000      0.000000
# 25%         10.000000      0.000000      0.000000
# ...

# %%
pip install dataprep
# Out:
# ...
#      ---------------------------------------- 9.9/9.9 MB 3.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 273.3/273.3 kB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 323.6/323.6 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.8/1.8 MB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 158.6/158.6 kB 3.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 96.9/96.9 kB 2.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 133.6/133.6 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 2.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 153.3/153.3 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 3.4 MB/s eta 0:00:00
# ...

# %%
from dataprep.eda import create_report
report = create_report(data)

report.save('eda_report')
# Out:
#   0%|          | 0/1441 [00:00<?, ?it/s]
# d:\Program\Anaconda\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# d:\Program\Anaconda\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# Report has been saved to eda_report.html!
